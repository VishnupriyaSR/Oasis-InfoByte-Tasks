# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.Loading the data

# %%
df=pd.read_csv("Unemployment.csv")
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %% [markdown]
# # 2.Exploring data

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
#check for null values
df.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df.tail(28)
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 740  West Bengal   31-05-2019    Monthly                              7.25
# 741  West Bengal   30-06-2019    Monthly                              7.38
# 742  West Bengal   31-07-2019    Monthly                              7.91
# 743  West Bengal   31-08-2019    Monthly                              7.27
# 744  West Bengal   30-09-2019    Monthly                              7.79
# 745  West Bengal   31-10-2019    Monthly                              7.83
# 746  West Bengal   30-11-2019    Monthly                              6.61
# 747  West Bengal   31-12-2019    Monthly                              7.24
# 748  West Bengal   31-01-2020    Monthly                              7.27
# 749  West Bengal   29-02-2020    Monthly                              7.55
# 750  West Bengal   31-03-2020    Monthly                              6.67
# ...

# %%
#dropping null values
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
df.shape
# Out:
# (740, 7)

# %%
pd.DataFrame(df.apply(lambda col:len(col.unique())),columns=["Unique Values Count"])
# Out:
#                                           Unique Values Count
# Region                                                     28
#  Date                                                      14
#  Frequency                                                  2
#  Estimated Unemployment Rate (%)                          624
#  Estimated Employed                                       740
#  Estimated Labour Participation Rate (%)                  626
# Area                                                        2

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 3.Data Wrangling

# %%
print(df.columns)
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
# Convert the 'Frequency' column to a categorical data type
df['Frequency'] = df[' Frequency'].astype('category')

# Convert the 'Region' column to a categorical data type
df['Region'] = df['Region'].astype('category')

# %% [markdown]
# # 4. Data Visualization

# %% [markdown]
# # 1. Distribution Plot of Unemployment Rate

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x=' Estimated Unemployment Rate (%)', kde=True)
plt.title('Distribution of Unemployment Rate')
plt.xlabel('Unemployment Rate (%)')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # 2.Scatter Plot of Unemployment Rate vs. Labour Participation Rate

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x=' Estimated Labour Participation Rate (%)', y=' Estimated Unemployment Rate (%)', hue='Region')
plt.title('Unemployment Rate vs. Labour Participation Rate')
plt.xlabel('Labour Participation Rate (%)')
plt.ylabel('Unemployment Rate (%)')
plt.show()

# %% [markdown]
# # 3.Bar Plot of Unemployment Rate by Region

# %%
# Plot
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='Region', y=' Estimated Unemployment Rate (%)')
plt.title('Unemployment Rate by Region')
plt.xlabel('Region')
plt.ylabel('Unemployment Rate (%)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above plot we observe that Tripura,Haryana and Jharkand have the highest Unemployment Rate and Meghalaya have least Unemployment Rate

# %% [markdown]
# # 4.Line Plot of Unemployment Rate Over Time

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x=' Date', y=' Estimated Unemployment Rate (%)')
plt.title('Unemployment Rate Over Time')
plt.xlabel('Date')
plt.ylabel('Unemployment Rate (%)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # In above analysis of the unemployment data, we observed a significant spike in the unemployment rate during March to May 2020. During this period, the unemployment rate increased to 24.88, which is notably higher than the average rate observed in the surrounding months. This increase may be indicative of underlying economic challenges or other factors(e.g.,due to corona) affecting the job market during that time.This sharp increase contrasts with the generally stable rates observed earlier in the year, suggesting a possible economic disruption or other significant factors affecting employment during this period.

# %% [markdown]
# # 5. Bar Plot for Distribution of Unemployment

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df, x='Area', y=' Estimated Unemployment Rate (%)')
plt.title('Unemployment Rate by Area')
plt.xlabel('Region')
plt.ylabel('Unemployment Rate (%)')
plt.show()

# %% [markdown]
# # From the above plot it is clear that Unemployment Rate is higher in Urban Areas than Rural Area

# %% [markdown]
# # 6.Box Plot

# %%
def plot(df,column):
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    sns.boxplot(data=df,x=column)
    plt.title(f'Box Plot for {column}')

    plt.subplot(1,2,2)
    sns.histplot(data=df,x=column,kde=True,bins=50)
    plt.title(f'Distribution Plot for {column}')

# %%
for i in [' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)']:
    plot(df,i)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # 7.Correlation between numeric columns

# %%
#Excluding non-numerical columns
numdf=df.select_dtypes(include=[np.number])
numdf.corr()
# Out:
#                                            Estimated Unemployment Rate (%)  \
#  Estimated Unemployment Rate (%)                                  1.000000
#  Estimated Employed                                              -0.222876
#  Estimated Labour Participation Rate (%)                          0.002558
#
#                                            Estimated Employed  \
#  Estimated Unemployment Rate (%)                    -0.222876
#  Estimated Employed                                  1.000000
#  Estimated Labour Participation Rate (%)             0.011300
#
#                                            Estimated Labour Participation Rate (%)
#  Estimated Unemployment Rate (%)                                          0.002558
#  Estimated Employed                                                       0.011300
#  Estimated Labour Participation Rate (%)                                  1.000000

# %% [markdown]
# # From the above heatmaps we got to know that, Estimated Unemployment Rate and Estimated Employed are negatively highly correlated.
